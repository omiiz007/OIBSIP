# %%
import numpy as np # linear algebra
import matplotlib.pyplot as plt
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
pq=pd.read_csv("Unemployment_Rate_upto_11_2020.csv")
pq
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)
# 0    Andhra Pradesh   31-01-2020          M                              5.48  \
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %%
pq.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)
# 0  Andhra Pradesh   31-01-2020          M                              5.48  \
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1
# 0             16635535                                     41.02    South  \
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# ...

# %%
pq.shape
# Out:
# (267, 9)

# %%
pq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
# Describing the data 

pq.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed
# count                        267.000000         2.670000e+02  \
# mean                          12.236929         1.396211e+07
# std                           10.803283         1.336632e+07
# min                            0.500000         1.175420e+05
# 25%                            4.845000         2.838930e+06
# 50%                            9.650000         9.732417e+06
# 75%                           16.755000         2.187869e+07
# max                           75.850000         5.943376e+07
#
#         Estimated Labour Participation Rate (%)   longitude    latitude
# count                                267.000000  267.000000  267.000000
# mean                                  41.681573   22.826048   80.532425
# std                                    7.845419    6.270731    5.831738
# min                                   16.770000   10.850500   71.192400
# ...

# %%
x=pq['Region']
x
# Out:
# 0      Andhra Pradesh
# 1      Andhra Pradesh
# 2      Andhra Pradesh
# 3      Andhra Pradesh
# 4      Andhra Pradesh
#             ...
# 262       West Bengal
# 263       West Bengal
# 264       West Bengal
# 265       West Bengal
# 266       West Bengal
# Name: Region, Length: 267, dtype: object

# %%
y=pq[' Estimated Unemployment Rate (%)']
y
# Out:
# 0       5.48
# 1       5.83
# 2       5.79
# 3      20.51
# 4      17.43
#        ...
# 262     7.29
# 263     6.83
# 264    14.87
# 265     9.35
# 266     9.98
# Name:  Estimated Unemployment Rate (%), Length: 267, dtype: float64

# %%
rs=pq.iloc[:,3]
rs
# Out:
# 0       5.48
# 1       5.83
# 2       5.79
# 3      20.51
# 4      17.43
#        ...
# 262     7.29
# 263     6.83
# 264    14.87
# 265     9.35
# 266     9.98
# Name:  Estimated Unemployment Rate (%), Length: 267, dtype: float64

# %%
# !pip install plotly
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import plotly.express as px

# %%
fg = px.bar(pq,x='Region',y=' Estimated Unemployment Rate (%)',color='Region',title='Unemployment rate',animation_frame=' Date',template='plotly')
fg.update_layout(xaxis={'categoryorder':'total descending'})
fg.show()
# Out:
# <div>                            <div id="cfccfff2-6893-4822-80f2-f6a1c8992476" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cfccfff2-6893-4822-80f2-f6a1c8992476")) {                    Plotly.newPlot(                        "cfccfff2-6893-4822-80f2-f6a1c8992476",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br> Date= 31-01-2020<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Andhra Pradesh","offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"textposition":"auto","x":["Andhra Pradesh"],"xaxis":"x","y":[5.48],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br> Date= 31-
# ...

# %%
fg = px.bar(pq,x='Region.1',y=' Estimated Unemployment Rate (%)',color='Region',title='Unemployment rate',animation_frame=' Date',template='plotly')
fg.update_layout(xaxis={'categoryorder':'total descending'})
fg.show()
# Out:
# <div>                            <div id="275d714b-fbab-484e-933f-8f3ffef89a09" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("275d714b-fbab-484e-933f-8f3ffef89a09")) {                    Plotly.newPlot(                        "275d714b-fbab-484e-933f-8f3ffef89a09",                        [{"alignmentgroup":"True","hovertemplate":"Region=Andhra Pradesh<br> Date= 31-01-2020<br>Region.1=%{x}<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Andhra Pradesh","offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"textposition":"auto","x":["South"],"xaxis":"x","y":[5.48],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=
# ...

# %%
# now we try to analyze data by using boxplot.

fg = px.box(pq,x='Region.1',y=' Estimated Unemployment Rate (%)',color='Region',title='Unemployment rate',animation_frame=' Date',template='plotly')
fg.update_layout(xaxis={'categoryorder':'total descending'})
fg.show()
# Out:
# <div>                            <div id="5395a2f6-df11-41f4-b8cc-36d64bcc7ab5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5395a2f6-df11-41f4-b8cc-36d64bcc7ab5")) {                    Plotly.newPlot(                        "5395a2f6-df11-41f4-b8cc-36d64bcc7ab5",                        [{"alignmentgroup":"True","hovertemplate":"Region=Andhra Pradesh<br> Date= 31-01-2020<br>Region.1=%{x}<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa"},"name":"Andhra Pradesh","notched":false,"offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"x":["South"],"x0":" ","xaxis":"x","y":[5.48],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Region=Assam<br> D
# ...

# %%
# Also we trying to analyze the data using the scattery plot.

fg = px.scatter(pq,x='Region.1',y=' Estimated Unemployment Rate (%)',color='Region',title='Unemployment rate',animation_frame=' Date',template='plotly')
fg.update_layout(xaxis={'categoryorder':'total descending'})
fg.show()
# Out:
# <div>                            <div id="58893a69-c212-402c-98e7-96207e239b75" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58893a69-c212-402c-98e7-96207e239b75")) {                    Plotly.newPlot(                        "58893a69-c212-402c-98e7-96207e239b75",                        [{"hovertemplate":"Region=Andhra Pradesh<br> Date= 31-01-2020<br>Region.1=%{x}<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Andhra Pradesh","orientation":"v","showlegend":true,"x":["South"],"xaxis":"x","y":[5.48],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Assam<br> Date= 31-01-2020<br>Region.1=%{x}<br> Estimated Unemployment Rate (%)=%{y}<
# ...

# %%
# Now analyzig the data using histogram.

fg = px.histogram(pq,x='Region.1',y=' Estimated Unemployment Rate (%)',color='Region',title='Unemployment rate',animation_frame=' Date',template='plotly')
fg.update_layout(xaxis={'categoryorder':'total descending'})
fg.show()
# Out:
# <div>                            <div id="65e0a95f-221a-4ff0-9646-11f43fdbca15" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65e0a95f-221a-4ff0-9646-11f43fdbca15")) {                    Plotly.newPlot(                        "65e0a95f-221a-4ff0-9646-11f43fdbca15",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Region=Andhra Pradesh<br> Date= 31-01-2020<br>Region.1=%{x}<br>sum of  Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Andhra Pradesh","offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"x":["South"],"xaxis":"x","y":[5.48],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","
# ...
